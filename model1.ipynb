# %%
import io
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds

(train_data, test_data), info = tfds.load('imdb_reviews/subwords8k', 
                                          split=(tfds.Split.TRAIN, tfds.Split.TEST),
                                          with_info=True, as_supervised=True)

encoder = info.features['text'].encoder
print(encoder.subwords[:2000])

padded_shapes =([None], ())
train_batches = train_data.shuffle(1000).padded_batch(100, padded_shapes=padded_shapes)
test_batches = test_data.shuffle(1000).padded_batch(100, padded_shapes=padded_shapes)


embedding_dim = 16
model = keras.Sequential([
    layers.Embedding(encoder.vocab_size, embedding_dim),
    layers.GlobalAveragePooling1D(),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_batches, epochs=100, validation_data=test_batches, validation_steps=20)

history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,9))
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim((0.5, 1))
plt.show()
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)
# ['the_', ', ', '. ', 'a_', 'and_', 'of_', 'to_', 's_', 'is_', 'br', 'in_', 'I_', 'that_', 'this_', 'it_', ' /><', ' />', 'was_', 'The_', 'as_', 't_', 'with_', 'for_', '.<', 'on_', 'but_', 'movie_', ' (', 'are_', 'his_', 'have_', 'film_', 'not_', 'ing_', 'be_', 'ed_', 'you_', ' "', 'it', 'd_', 'an_', 'he_', 'by_', 'at_', 'one_', 'who_', 'y_', 'from_', 'e_', 'or_', 'all_', 'like_', 'they_', '" ', 'so_', 'just_', 'has_', ') ', 'her_', 'about_', 'out_', 'This_', 'some_', 'ly_', 'movie', 'film', 'very_', 'more_', 'It_', 'would_', 'what_', 'when_', 'which_', 'good_', 'if_', 'up_', 'only_', 'even_', 'their_', 'had_', 'really_', 'my_', 'can_', 'no_', 'were_', 'see_', 'she_', '? ', 'than_', '! ', 'there_', 'get_', 'been_', 'into_', ' - ', 'will_', 'much_', 'story_', 'because_', 'ing', 'time_', 'n_', 'we_', 'ed', 'me_', ': ', 'most_', 'other_', 'don', 'do_', 'm_', 'es_', 'how_', 'also_', 'make_', 'its_', 'could_', 'first_', 'any_', "' ", 'people_', 'great_', 've_', 'ly', 'er_', 'made_', 'r_', 'But_', 'think_', " '", 'i_', 'bad_', 'A_', 'And_', 'It', 'on', '; ', 'him_', 'being_', 'never_', 'way_', 'that', 'many_', 'then_', 'where_', 'two_', 'In_', 'after_', 'too_', 'little_', 'you', '), ', 'well_', 'ng_', 'your_', 'If_', 'l_', '). ', 'does_', 'ever_', 'them_', 'did_', 'watch_', 'know_', 'seen_', 'time', 'er', 'character_', 'over_', 'characters_', 'movies_', 'man_', 'There_', 'love_', 'best_', 'still_', 'off_', 'such_', 'in', 'should_', 'the', 're_', 'He_', 'plot_', 'films_', 'go_', 'these_', 'acting_', 'doesn', 'es', 'show_', 'through_', 'better_', 'al_', 'something_', 'didn', 'back_', 'those_', 'us_', 'less_', '...', 'say_', 'is', 'one', 'makes_', 'can', 'and', 'all', 'ion_', 'find_', 'scene_', 'old_', 'real_', 'few_', 'going_', 'well', 'actually_', 'watching_', 'life_', 'me', '. <', 'o_', 'man', 'there', 'scenes_', 'same_', 'he', 'end_', 'this', '... ', 'k_', 'while_', 'thing_', 'of', 'look_', 'quite_', 'out', 'lot_', 'want_', 'why_', 'seems_', 'every_', 'll_', 'pretty_', 'got_', 'able_', 'nothing_', 'good', 'As_', 'story', ' & ', 'another_', 'take_', 'to', 'years_', 'between_', 'give_', 'am_', 'work_', 'isn', 'part_', 'before_', 'actors_', 'may_', 'gets_', 'young_', 'down_', 'around_', 'ng', 'thought_', 'though_', 'end', 'without_', 'What_', 'They_', 'things_', 'life', 'always_', 'must_', 'cast_', 'almost_', 'h_', '10', 'saw_', 'own_', 'here', 'bit_', 'come_', 'both_', 'might_', 'g_', 'whole_', 'new_', 'director_', 'them', 'horror_', 'ce', 'You_', 'least_', 'bad', 'big_', 'enough_', 'him', 'feel_', 'probably_', 'up', 'here_', 'making_', 'long_', 'her', 'st_', 'kind_', '--', 'original_', 'fact_', 'rather_', 'or', 'far_', 'nt_', 'played_', 'found_', 'last_', 'movies', 'When_', 'so', '", ', 'comes_', 'action_', 'She_', 've', 'our_', 'anything_', 'funny_', 'ion', 'right_', 'way', 'trying_', 'now_', 'ous_', 'each_', 'done_', 'since_', 'ic_', 'point_', '". ', 'wasn', 'interesting_', 'c_', 'worst_', 'te_', 'le_', 'ble_', 'ty_', 'looks_', 'show', 'put_', 'looking_', 'especially_', 'believe_', 'en_', 'goes_', 'over', 'ce_', 'p_', 'films', 'hard_', 'main_', 'be', 'having_', 'ry', 'TV_', 'worth_', 'One_', 'do', 'al', 're', 'again', 'series_', 'takes_', 'guy_', 'family_', 'seem_', 'plays_', 'role_', 'away_', 'world_', 'My_', 'character', ', "', 'performance_', '2_', 'So_', 'watched_', 'John_', 'th_', 'plot', 'script_', 'For_', 'sure_', 'characters', 'set_', 'different_', 'minutes_', 'All_', 'American_', 'anyone_', 'Not_', 'music_', 'ry_', 'shows_', 'too', 'son_', 'en', 'day_', 'use_', 'someone_', 'for', 'woman_', 'yet_', '." ', 'during_', 'she', 'ro', '- ', 'times_', 'left_', 'used_', 'le', 'three_', 'play_', 'work', 'ness_', 'We_', 'girl_', 'comedy_', 'ment_', 'an', 'simply_', 'off', 'ies_', 'funny', 'ne', 'acting', 'That_', 'fun_', 'completely_', 'st', 'seeing_', 'us', 'te', 'special_', 'ation_', 'as', 'ive_', 'ful_', 'read_', 'reason_', 'co', 'need_', 'sa', 'true_', 'ted_', 'like', 'ck', 'place_', 'they', '10_', 'However', 'until_', 'rest_', ' ...
# Epoch 1/100
# 250/250 [==============================] - 6s 26ms/step - loss: 0.6904 - accuracy: 0.5827 - val_loss: 0.6872 - val_accuracy: 0.6670
# Epoch 2/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.6780 - accuracy: 0.6801 - val_loss: 0.6708 - val_accuracy: 0.7125
# Epoch 3/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.6536 - accuracy: 0.7337 - val_loss: 0.6446 - val_accuracy: 0.7545
# Epoch 4/100
# 250/250 [==============================] - 7s 28ms/step - loss: 0.6219 - accuracy: 0.7619 - val_loss: 0.6103 - val_accuracy: 0.7745
# Epoch 5/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.5896 - accuracy: 0.7819 - val_loss: 0.5856 - val_accuracy: 0.7645
# Epoch 6/100
# 250/250 [==============================] - 7s 28ms/step - loss: 0.5571 - accuracy: 0.8024 - val_loss: 0.5517 - val_accuracy: 0.7940
# Epoch 7/100
# 250/250 [==============================] - 6s 24ms/step - loss: 0.5270 - accuracy: 0.8163 - val_loss: 0.5261 - val_accuracy: 0.8055
# Epoch 8/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.5008 - accuracy: 0.8324 - val_loss: 0.5013 - val_accuracy: 0.8140
# Epoch 9/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.4747 - accuracy: 0.8441 - val_loss: 0.4868 - val_accuracy: 0.8240
# Epoch 10/100
# 250/250 [==============================] - 6s 24ms/step - loss: 0.4538 - accuracy: 0.8520 - val_loss: 0.4712 - val_accuracy: 0.8245
# Epoch 11/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4314 - accuracy: 0.8623 - val_loss: 0.4552 - val_accuracy: 0.8420
# Epoch 12/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.4135 - accuracy: 0.8699 - val_loss: 0.4343 - val_accuracy: 0.8490
# Epoch 13/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.3947 - accuracy: 0.8744 - val_loss: 0.4172 - val_accuracy: 0.8540
# Epoch 14/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.3808 - accuracy: 0.8811 - val_loss: 0.4049 - val_accuracy: 0.8545
# Epoch 15/100
# 250/250 [==============================] - 9s 38ms/step - loss: 0.3655 - accuracy: 0.8829 - val_loss: 0.4020 - val_accuracy: 0.8520
# Epoch 16/100
# 250/250 [==============================] - 11s 43ms/step - loss: 0.3537 - accuracy: 0.8861 - val_loss: 0.3842 - val_accuracy: 0.8690
# Epoch 17/100
# 250/250 [==============================] - 9s 34ms/step - loss: 0.3407 - accuracy: 0.8907 - val_loss: 0.3984 - val_accuracy: 0.8625
# Epoch 18/100
# 250/250 [==============================] - 8s 33ms/step - loss: 0.3319 - accuracy: 0.8923 - val_loss: 0.3766 - val_accuracy: 0.8710
# Epoch 19/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.3215 - accuracy: 0.8955 - val_loss: 0.3704 - val_accuracy: 0.8690
# Epoch 20/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.3108 - accuracy: 0.8978 - val_loss: 0.3673 - val_accuracy: 0.8645
# Epoch 21/100
# 250/250 [==============================] - 10s 38ms/step - loss: 0.3032 - accuracy: 0.9006 - val_loss: 0.3510 - val_accuracy: 0.8730
# Epoch 22/100
# 250/250 [==============================] - 10s 40ms/step - loss: 0.2955 - accuracy: 0.9035 - val_loss: 0.3507 - val_accuracy: 0.8750
# Epoch 23/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.2873 - accuracy: 0.9060 - val_loss: 0.3476 - val_accuracy: 0.8715
# Epoch 24/100
# 250/250 [==============================] - 7s 26ms/step - loss: 0.2805 - accuracy: 0.9068 - val_loss: 0.3344 - val_accuracy: 0.8760
# Epoch 25/100
# 250/250 [==============================] - 7s 28ms/step - loss: 0.2742 - accuracy: 0.9092 - val_loss: 0.3446 - val_accuracy: 0.8735
# Epoch 26/100
# 250/250 [==============================] - 6s 26ms/step - loss: 0.2680 - accuracy: 0.9110 - val_loss: 0.3363 - val_accuracy: 0.8775
# Epoch 27/100
# 250/250 [==============================] - 6s 24ms/step - loss: 0.2629 - accuracy: 0.9135 - val_loss: 0.3343 - val_accuracy: 0.8720
# Epoch 28/100
# 250/250 [==============================] - 7s 26ms/step - loss: 0.2555 - accuracy: 0.9147 - val_loss: 0.3256 - val_accuracy: 0.8760
# Epoch 29/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.2505 - accuracy: 0.9150 - val_loss: 0.3339 - val_accuracy: 0.8775
# Epoch 30/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.2464 - accuracy: 0.9167 - val_loss: 0.3318 - val_accuracy: 0.8725
# Epoch 31/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.2414 - accuracy: 0.9180 - val_loss: 0.3237 - val_accuracy: 0.8800
# Epoch 32/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.2368 - accuracy: 0.9203 - val_loss: 0.3337 - val_accuracy: 0.8725
# Epoch 33/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.2318 - accuracy: 0.9212 - val_loss: 0.3225 - val_accuracy: 0.8755
# Epoch 34/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.2270 - accuracy: 0.9233 - val_loss: 0.3318 - val_accuracy: 0.8765
# Epoch 35/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2242 - accuracy: 0.9235 - val_loss: 0.3262 - val_accuracy: 0.8775
# Epoch 36/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2185 - accuracy: 0.9264 - val_loss: 0.3233 - val_accuracy: 0.8750
# Epoch 37/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2167 - accuracy: 0.9256 - val_loss: 0.3214 - val_accuracy: 0.8785
# Epoch 38/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2123 - accuracy: 0.9276 - val_loss: 0.3214 - val_accuracy: 0.8865
# Epoch 39/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2099 - accuracy: 0.9287 - val_loss: 0.3299 - val_accuracy: 0.8770
# Epoch 40/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.2056 - accuracy: 0.9297 - val_loss: 0.3195 - val_accuracy: 0.8795
# Epoch 41/100
# 250/250 [==============================] - 6s 24ms/step - loss: 0.2013 - accuracy: 0.9314 - val_loss: 0.3207 - val_accuracy: 0.8740
# Epoch 42/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.1993 - accuracy: 0.9326 - val_loss: 0.2977 - val_accuracy: 0.8880
# Epoch 43/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.1944 - accuracy: 0.9341 - val_loss: 0.3190 - val_accuracy: 0.8795
# Epoch 44/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.1930 - accuracy: 0.9344 - val_loss: 0.3266 - val_accuracy: 0.8795
# Epoch 45/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.1909 - accuracy: 0.9353 - val_loss: 0.3183 - val_accuracy: 0.8825
# Epoch 46/100
# 250/250 [==============================] - 8s 33ms/step - loss: 0.1873 - accuracy: 0.9363 - val_loss: 0.3264 - val_accuracy: 0.8810
# Epoch 47/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.1847 - accuracy: 0.9376 - val_loss: 0.3055 - val_accuracy: 0.8835
# Epoch 48/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.1814 - accuracy: 0.9380 - val_loss: 0.3202 - val_accuracy: 0.8805
# Epoch 49/100
# 250/250 [==============================] - 7s 28ms/step - loss: 0.1798 - accuracy: 0.9392 - val_loss: 0.3322 - val_accuracy: 0.8760
# Epoch 50/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.1773 - accuracy: 0.9408 - val_loss: 0.3270 - val_accuracy: 0.8820
# Epoch 51/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.1744 - accuracy: 0.9408 - val_loss: 0.3316 - val_accuracy: 0.8730
# Epoch 52/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.1719 - accuracy: 0.9418 - val_loss: 0.3255 - val_accuracy: 0.8825
# Epoch 53/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1700 - accuracy: 0.9424 - val_loss: 0.3264 - val_accuracy: 0.8815
# Epoch 54/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1659 - accuracy: 0.9437 - val_loss: 0.3276 - val_accuracy: 0.8800
# Epoch 55/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1652 - accuracy: 0.9440 - val_loss: 0.3388 - val_accuracy: 0.8780
# Epoch 56/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1632 - accuracy: 0.9450 - val_loss: 0.3279 - val_accuracy: 0.8750
# Epoch 57/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.1604 - accuracy: 0.9454 - val_loss: 0.3268 - val_accuracy: 0.8790
# Epoch 58/100
# 250/250 [==============================] - 6s 23ms/step - loss: 0.1587 - accuracy: 0.9474 - val_loss: 0.3295 - val_accuracy: 0.8785
# Epoch 59/100
# 250/250 [==============================] - 6s 22ms/step - loss: 0.1566 - accuracy: 0.9474 - val_loss: 0.3465 - val_accuracy: 0.8750
# Epoch 60/100
# 250/250 [==============================] - 6s 25ms/step - loss: 0.1545 - accuracy: 0.9475 - val_loss: 0.3541 - val_accuracy: 0.8670
# Epoch 61/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.1525 - accuracy: 0.9485 - val_loss: 0.3570 - val_accuracy: 0.8750
# Epoch 62/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.1508 - accuracy: 0.9491 - val_loss: 0.3292 - val_accuracy: 0.8760
# Epoch 63/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.1489 - accuracy: 0.9505 - val_loss: 0.3435 - val_accuracy: 0.8760
# Epoch 64/100
# 250/250 [==============================] - 7s 26ms/step - loss: 0.1474 - accuracy: 0.9507 - val_loss: 0.3448 - val_accuracy: 0.8745
# Epoch 65/100
# 250/250 [==============================] - 7s 27ms/step - loss: 0.1456 - accuracy: 0.9519 - val_loss: 0.3500 - val_accuracy: 0.8690
# Epoch 66/100
# 170/250 [===================>..........] - ETA: 1s - loss: 0.1444 - accuracy: 0.9521

# %%
# embedding_layer = layers.Embedding(1000, 5)
# result = embedding_layer(tf.constant([1,2,3]))

# print(result.numpy().shape)

# %%
(train_data, test_data), info = tfds.load('IMDB/subworks8k', split=(tfds.Split.TRAIN, tfds.Split.TEST), with_info=True, as_supervised=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e157d80bffbf> in <module>
# ----> 1 (train_data, test_data), info = tfds.load('IMDB/subworks8k', split=(tfds.Split.TRAIN, tfds.Split.TEST), with_info=True, as_supervised=True)
#
# NameError: name 'tfds' is not defined
